# %%
import numpy as np
import yfinance as yf
import pandas as pd

from matplotlib import pyplot as plt

# %%
sp500_hist = pd.read_csv(
    "./data/sp500_hist_prices.csv",
    parse_dates=['Date'],
    index_col='Date')

sp500_hist = sp500_hist.loc['2014-01-01':,]
sp500_hist.dropna(axis=1, inplace=True)

print(f'Shape: {sp500_hist.shape}')
sp500_hist.head()


gspc = yf.download(
    tickers="^GSPC", 
    start=sp500_hist.index[0].strftime(format="%Y-%m-%d"), 
    end=sp500_hist.index[-1].strftime(format="%Y-%m-%d")
)['Adj Close']
# Out:
# Shape: (2266, 470)
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(12,6))
plt.plot(gspc)
plt.title("S&P500 Index")
plt.ylabel("Indexpoints")
plt.axvspan("2014-01-02", "2019-01-01", facecolor='#A3CC8A', alpha=0.2)
plt.axvspan("2019-01-01", "2021-01-01", facecolor='#FFD96D', alpha=0.2)
plt.axvspan("2021-01-01", "2023-01-01", facecolor='#AEAEAE', alpha=0.2)

plt.show()
